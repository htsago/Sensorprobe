# %%
# %matplotlib qt5
import pandas as pd
import matplotlib.pyplot as plt

# %%
dd= pd.read_csv("D:\Sensorprobe\drilling_pause_new.csv")

# %%
dd
# Out:
#          R1_1      R1_2      R1_3      R1_4      R1_5      R1_6      R3_1  \
# 0    0.003227  0.009945  0.030936  0.002887  0.018775  0.032052  0.000837
# 1    0.006602  0.021662  0.041919  0.000960  0.026368  0.059063  0.000570
# 2    0.008419  0.027423  0.041625  0.001170  0.026871  0.077290  0.000433
# 3    0.011671  0.030058  0.039765  0.001264  0.026654  0.083463  0.001178
# 4    0.012235  0.030764  0.037809  0.001056  0.025547  0.087332  0.000725
# ..        ...       ...       ...       ...       ...       ...       ...
# 370  0.014171  0.032654  0.035576  0.034272  0.007879  0.027695  0.000764
# 371  0.010742  0.025302  0.040376  0.034026  0.007981  0.023229  0.000941
# 372  0.007760  0.019023  0.040580  0.030143  0.006956  0.020983  0.000945
# 373  0.002831  0.016140  0.034334  0.020286  0.005603  0.018018  0.000729
# 374  0.004164  0.015263  0.027296  0.016291  0.005694  0.014199  0.000854
#
#          R3_2      R3_3      R3_4      R3_5      R3_6      R4_1      R4_2  \
# ...

# %%
plt.title('Activity()', fontsize=22, fontweight='bold')
plt.xlabel('Data points', fontsize=18, fontweight='bold')
plt.ylabel('Amplitude(um)', fontsize=18, fontweight='bold')
plt.grid(True)
plt.legend(['R1_1'])

# Set the text size of the tick labels on both axes
plt.tick_params(axis='both', labelsize=18)
plt.plot(dd.index, dd[['R1_1', 'R1_2','R1_3','R1_4','R1_5','R1_6','R3_1', 'R3_2','R3_3','R3_4','R3_5','R3_6','R4_1', 'R4_2', 'R4_3', 'R4_4', 'R4_5', 'R4_6']])

# %%
# dd["activity"]="pause"
# dd["class"]='0'

# %%
dd
# Out:
#          R1_1      R1_2      R1_3      R1_4      R1_5      R1_6      R3_1  \
# 0    0.003227  0.009945  0.030936  0.002887  0.018775  0.032052  0.000837
# 1    0.006602  0.021662  0.041919  0.000960  0.026368  0.059063  0.000570
# 2    0.008419  0.027423  0.041625  0.001170  0.026871  0.077290  0.000433
# 3    0.011671  0.030058  0.039765  0.001264  0.026654  0.083463  0.001178
# 4    0.012235  0.030764  0.037809  0.001056  0.025547  0.087332  0.000725
# ..        ...       ...       ...       ...       ...       ...       ...
# 370  0.014171  0.032654  0.035576  0.034272  0.007879  0.027695  0.000764
# 371  0.010742  0.025302  0.040376  0.034026  0.007981  0.023229  0.000941
# 372  0.007760  0.019023  0.040580  0.030143  0.006956  0.020983  0.000945
# 373  0.002831  0.016140  0.034334  0.020286  0.005603  0.018018  0.000729
# 374  0.004164  0.015263  0.027296  0.016291  0.005694  0.014199  0.000854
#
#          R3_2      R3_3      R3_4      R3_5      R3_6      R4_1      R4_2  \
# ...

# %%
#dd.to_csv('/Sensorprobe/screw_pause_new.csv', index=False)
