# %%
# %matplotlib qt5
import pandas as pd
import matplotlib.pyplot as plt

# %%
dd= pd.read_csv("D:\Sensorprobe\cluster_1.csv")

# %%
dd
# Out:
#          R1_1      R1_3      R1_5      R1_7      R1_9     R1_11      R4_1  \
# 0    0.010456  0.012609  0.048944  0.023628  0.028579  0.044325  0.007687
# 1    0.018967  0.031313  0.047484  0.027669  0.027593  0.051520  0.009314
# 2    0.025690  0.040297  0.038624  0.029291  0.026915  0.052766  0.008823
# 3    0.027730  0.041703  0.035279  0.030588  0.025634  0.053420  0.008484
# 4    0.025543  0.042558  0.034523  0.032289  0.025092  0.053079  0.007341
# ..        ...       ...       ...       ...       ...       ...       ...
# 224  0.029109  0.036661  0.025025  0.032044  0.013693  0.026900  0.009039
# 225  0.030350  0.035869  0.024869  0.032358  0.013860  0.028983  0.009797
# 226  0.029146  0.037118  0.025915  0.032055  0.014492  0.030290  0.009314
# 227  0.030513  0.037563  0.024830  0.035236  0.016564  0.029914  0.009524
# 228  0.030045  0.038512  0.025621  0.035705  0.015363  0.026813  0.009170
#
#          R4_3      R4_5      R4_7      R4_9     R4_11 class activity
# 0    0.010499  0.037551  0.013634  0.043337  0.053210     2  sanding
# 1    0.013840  0.054837  0.027924  0.049712  0.068056     2  sanding
# 2    0.016865  0.051688  0.023862  0.052566  0.069167     2  sanding
# 3    0.020366  0.043546  0.013400  0.052794  0.063528     2  sanding
# 4    0.024078  0.033458  0.004163  0.054840  0.058438     2  sanding
# ..        ...       ...       ...       ...       ...   ...      ...
# 224  0.014800  0.031135  0.027076  0.075822  0.075610     2  sanding
# 225  0.014214  0.031045  0.026413  0.074981  0.075379     2  sanding
# 226  0.014322  0.032410  0.022797  0.072922  0.075461     2  sanding
# 227  0.012769  0.038576  0.005627  0.054172  0.084328     2  sanding
# 228  0.011306  0.036208  0.015969  0.053221  0.071480     2  sanding
#
# [229 rows x 14 columns]

# %%
plt.title('Activity()', fontsize=22, fontweight='bold')
plt.xlabel('Data points', fontsize=18, fontweight='bold')
plt.ylabel('Amplitude(um)', fontsize=18, fontweight='bold')
plt.grid(True)
plt.legend(['R1_1'])

# Set the text size of the tick labels on both axes
plt.tick_params(axis='both', labelsize=18)
plt.plot(dd.index, dd[['R1_1', 'R1_3','R1_5','R1_7','R1_9','R1_11','R4_1', 'R4_3', 'R4_5', 'R4_7', 'R4_9', 'R4_11']])
# Out:
# [<matplotlib.lines.Line2D at 0x2dc439be5d0>,
#  <matplotlib.lines.Line2D at 0x2dc43a23550>,
#  <matplotlib.lines.Line2D at 0x2dc43a4e710>,
#  <matplotlib.lines.Line2D at 0x2dc43a4eb10>,
#  <matplotlib.lines.Line2D at 0x2dc43a4ee50>,
#  <matplotlib.lines.Line2D at 0x2dc43a4f210>,
#  <matplotlib.lines.Line2D at 0x2dc43a4f790>,
#  <matplotlib.lines.Line2D at 0x2dc43a4fbd0>,
#  <matplotlib.lines.Line2D at 0x2dc43a4ef50>,
#  <matplotlib.lines.Line2D at 0x2dc43a58390>,
#  <matplotlib.lines.Line2D at 0x2dc43a006d0>,
#  <matplotlib.lines.Line2D at 0x2dc43a58950>]

# %%
dd["activity"]="sanding"
dd["class"]='2'

# %%
dd
# Out:
#          R1_1      R1_3      R1_5      R1_7      R1_9     R1_11      R4_1  \
# 0    0.010456  0.012609  0.048944  0.023628  0.028579  0.044325  0.007687
# 1    0.018967  0.031313  0.047484  0.027669  0.027593  0.051520  0.009314
# 2    0.025690  0.040297  0.038624  0.029291  0.026915  0.052766  0.008823
# 3    0.027730  0.041703  0.035279  0.030588  0.025634  0.053420  0.008484
# 4    0.025543  0.042558  0.034523  0.032289  0.025092  0.053079  0.007341
# ..        ...       ...       ...       ...       ...       ...       ...
# 224  0.029109  0.036661  0.025025  0.032044  0.013693  0.026900  0.009039
# 225  0.030350  0.035869  0.024869  0.032358  0.013860  0.028983  0.009797
# 226  0.029146  0.037118  0.025915  0.032055  0.014492  0.030290  0.009314
# 227  0.030513  0.037563  0.024830  0.035236  0.016564  0.029914  0.009524
# 228  0.030045  0.038512  0.025621  0.035705  0.015363  0.026813  0.009170
#
#          R4_3      R4_5      R4_7      R4_9     R4_11 class activity
# 0    0.010499  0.037551  0.013634  0.043337  0.053210     2  sanding
# 1    0.013840  0.054837  0.027924  0.049712  0.068056     2  sanding
# 2    0.016865  0.051688  0.023862  0.052566  0.069167     2  sanding
# 3    0.020366  0.043546  0.013400  0.052794  0.063528     2  sanding
# 4    0.024078  0.033458  0.004163  0.054840  0.058438     2  sanding
# ..        ...       ...       ...       ...       ...   ...      ...
# 224  0.014800  0.031135  0.027076  0.075822  0.075610     2  sanding
# 225  0.014214  0.031045  0.026413  0.074981  0.075379     2  sanding
# 226  0.014322  0.032410  0.022797  0.072922  0.075461     2  sanding
# 227  0.012769  0.038576  0.005627  0.054172  0.084328     2  sanding
# 228  0.011306  0.036208  0.015969  0.053221  0.071480     2  sanding
#
# [229 rows x 14 columns]

# %%
#dd.to_csv('/Sensorprobe/sanding_activity.csv', index=False)
