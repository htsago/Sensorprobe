# %%
# %matplotlib qt5
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
dd= pd.read_csv("D:\Sensorprobe\cluster_1.csv")

# %%
dd
# Out:
#          R1_1      R1_3      R1_5      R1_7      R1_9     R1_11      R4_1  \
# 0    0.007135  0.011782  0.010183  0.010032  0.016003  0.044630  0.007779
# 1    0.010521  0.018473  0.018318  0.014442  0.014373  0.036914  0.008326
# 2    0.009569  0.020290  0.023501  0.015097  0.014382  0.040771  0.009035
# 3    0.011631  0.021607  0.029435  0.017994  0.018940  0.044553  0.009020
# 4    0.010421  0.022111  0.031152  0.019377  0.020891  0.043398  0.009162
# ..        ...       ...       ...       ...       ...       ...       ...
# 108  0.014966  0.022371  0.020246  0.013649  0.011597  0.032933  0.008946
# 109  0.015731  0.022602  0.019757  0.014350  0.010747  0.032727  0.009081
# 110  0.014424  0.020331  0.018342  0.012139  0.008191  0.030358  0.008689
# 111  0.011247  0.014610  0.012219  0.015928  0.009509  0.034282  0.008572
# 112  0.009594  0.004513  0.013028  0.019973  0.007857  0.036207  0.007167
#
#          R4_3      R4_5      R4_7      R4_9     R4_11  class
# ...

# %%
plt.title('Activity()', fontsize=22, fontweight='bold')
plt.xlabel('Data points', fontsize=18, fontweight='bold')
plt.ylabel('Amplitude(um)', fontsize=18, fontweight='bold')
plt.grid(True)
plt.legend(['R1_1'])

# Set the text size of the tick labels on both axes
plt.tick_params(axis='both', labelsize=18)
plt.plot(dd.index, dd[['R1_1', 'R1_3','R1_5','R1_7','R1_9','R1_11','R4_1', 'R4_3', 'R4_5', 'R4_7', 'R4_9', 'R4_11']])

# %%
dd["activity"]="painting"

# %%
dd
# Out:
#          R1_1      R1_3      R1_5      R1_7      R1_9     R1_11      R4_1  \
# 0    0.007135  0.011782  0.010183  0.010032  0.016003  0.044630  0.007779
# 1    0.010521  0.018473  0.018318  0.014442  0.014373  0.036914  0.008326
# 2    0.009569  0.020290  0.023501  0.015097  0.014382  0.040771  0.009035
# 3    0.011631  0.021607  0.029435  0.017994  0.018940  0.044553  0.009020
# 4    0.010421  0.022111  0.031152  0.019377  0.020891  0.043398  0.009162
# ..        ...       ...       ...       ...       ...       ...       ...
# 108  0.014966  0.022371  0.020246  0.013649  0.011597  0.032933  0.008946
# 109  0.015731  0.022602  0.019757  0.014350  0.010747  0.032727  0.009081
# 110  0.014424  0.020331  0.018342  0.012139  0.008191  0.030358  0.008689
# 111  0.011247  0.014610  0.012219  0.015928  0.009509  0.034282  0.008572
# 112  0.009594  0.004513  0.013028  0.019973  0.007857  0.036207  0.007167
#
#          R4_3      R4_5      R4_7      R4_9     R4_11  class  activity
# ...

# %%
dd.to_csv('/Sensorprobe/painting_activity.csv', index=False)
